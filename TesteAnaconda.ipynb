# %%
print("hello")
# Out:
# hello

# %%
first_name = "barbara"
print(first_name)
# Out:
# barbara

# %%
second_name = "thiago" 
print(second_name)
# Out:
# thiago

# %%
type(first_name)
# Out:
# str

# %%
my_text = "legalzinha você né?"

# %%
print(my_text)
# Out:
# legalzinha você né?

# %%
numero_casa = 321
print(numero_casa)
type(numero_casa)
# Out:
# 321
# int

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(my_list[2])
# Out:
# 3
